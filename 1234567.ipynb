# %% [markdown]
# <a href="https://colab.research.google.com/github/Akesh656/Akesh686/blob/main/1234567.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file_path = "C:/Users/IKSHITHA/Downloads/car_price_dataset.csv"
df = pd.read_csv("car_price_dataset.csv")
feature1 = "engine_size"
feature2 = "price"
Correlation = df[feature1].corr(df[feature2])
print(f"Correlation between {feature1} and {feature2}: {Correlation}")
# Out:
#      <input type="file" id="files-88a1e96a-8b5f-4e2d-bcaf-260f13470590" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88a1e96a-8b5f-4e2d-bcaf-260f13470590">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)
data = {
    "Study Hours" : np.random.randint(1,10,50),
    "Marks" : np.random.randint(30,100,50),
    "Screen Time" : np.random.randint(1,7,50),
    "Sleep Hours" : np.random.randint(4,10,50),
    "Travelling Time" : np.random.randint(1,5,50)
}
df = pd.DataFrame(data)
corr = df.corr()

feature1 = "Study Hours"
feature2 = "Marks"
correlation_value = df[feature1].corr(df[feature2])
print(f"Correlation between {feature1} and {feature2}: {correlation_value}:.2f")


plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=".2f",linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation between Study Hours and Marks: -0.3060211871793111:.2f
